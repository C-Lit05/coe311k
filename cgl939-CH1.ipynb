# %%
import matplotlib.pyplot as plt
import numpy as np
##I am so so so soooo washed up
##full disclosure, had to relearn all the syntax
x = np.linspace(0,50,100)
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x, x**2)
plt.subplot(2,2,2)
plt.scatter(x, np.sin(x))
plt.subplot(2,2,3)
plt.bar([1,2,3,4], [3,8,4,2])
plt.subplot(2,2,4)
plt.hist(np.random.randn(100), bins=10)

plt.tight_layout()
plt.show()
